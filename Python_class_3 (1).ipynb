# %%
print(2*2)
# Out:
# 4

# %%
print(2*3)
# Out:
# 6

# %%
# ipynb:- I Python notebook

# %%
for i in range(10):
    print('Hello Python')
# Out:
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python
# Hello Python

# %%
# gberhjgnwre
# gwer
# gwr
# egh
# etyh
# gsr
# th
# fyhy
# strg

# %% [markdown]
# # Class First

# %% [markdown]
# # Topic 1
# ## Topic 2
# ### Topic 3
# #### Topic 4
# ##### Topic 5
# ###### Topic 6

# %% [markdown]
# ### The following are some of the features in Python that are discussed below:
# - Easy to Code. Python is a very high-level programming language, yet it is effortless to learn. ...
# - Easy to Read. ...
# - Free and Open-Source. ...
# - Robust **Standard Library**. ...
# - `Interpreted`. ...
# - Portable. ...
# - Object-Oriented and Procedure-Oriented. ...
# - Extensible.

# %%
# print(2*2)

# %% [markdown]
# - Print ka matlab result ko **show karna** hota hai

# %% [markdown]
# ![what-is-python-presentation-230326123553-7e24f9d9-thumbnail.jpg](attachment:what-is-python-presentation-230326123553-7e24f9d9-thumbnail.jpg)

# %% [markdown]
# ![Ppython-process.webp](attachment:Ppython-process.webp)

# %%
# while True:
#     print('Don!!')

# %%
# print()

# %%
# single line code
# multiline code
# script:- 1 or more pages of code
# module:- multiple scripts
# softwares

# %%
# types of data 

# data types()


x = 2098754

# %%
print(x)
# Out:
# 2098754

# %%
a = 'python'
# string

# %%
print(a)
# Out:
# python

# %%
s = 'Aman Sharma'

print(s)
# Out:
# Aman Sharma

# %%
joker = 'karan','rohit','mohan','ajay','rishi'

# %%
print(joker)
# Out:
# ('karan', 'rohit', 'mohan', 'ajay', 'rishi')

# %%
# collection data type:- tuple

# %%
s = ('ajay','rohit','mohit')

# %%
print(s)
# Out:
# ('ajay', 'rohit', 'mohit')

# %%
print(s)
# Out:
# ('ajay', 'rohit', 'mohit')

# %%
d = [1,2,3,34,'mohan','karan']

# %%
## collection data type:- list
print(d)
# Out:
# [1, 2, 3, 34, 'mohan', 'karan']

# %%
# float
adf = 56.7
print(adf)
# Out:
# 56.7

# %%
# integer
a = 456
print(a)
# Out:
# -456

# %%
# type()

# %%
type(a)
# Out:
# int

# %%
type(adf)
# Out:
# float

# %%
s = 'mohan'
type(s)
# Out:
# str

# %%
f = 'karan','ravi','ajay'

print(f)
# Out:
# ('karan', 'ravi', 'ajay')

# %%
type(f)
# Out:
# tuple

# %%
df = [12,32,4,'Ajay','Ravi']

print(df)
# Out:
# [12, 32, 4, 'Ajay', 'Ravi']

# %%
type(df)
# Out:
# list

# %%
# complex

# %%
a = 34-56j

print(a)
# Out:
# (34-56j)

# %%
type(a)
# Out:
# complex

# %%
# numeric data type:- int,float,complex

# %%
# collection:- str,list,tuple

# %%
# boolean data type bool

a = True

# %%
print(a)
# Out:
# True

# %%
b = False

# %%
type(b)
# Out:
# bool

# %%
# set:- unique collection of a unordered items

# %%
r = {1,1,11,11,1,1,1,1,1,1,2,2,2,22,3,3,3,3,4,4,44,4,5,5,5}

r
# Out:
# {1, 2, 3, 4, 5, 11, 22, 44}

# %%
type(r)
# Out:
# set

# %%
a =
# Out:
#   Cell In[69], line 1
#     a =
#         ^
# SyntaxError: invalid syntax

# %%
# None data type(special data type)

# %%
d = None

# %%
type(d)
# Out:
# NoneType

# %%
# last datatype

# mapping:- dictionary data type

# %%
a = {'name':'Mohan'}

# %%
print(a)
# Out:
# {'name': 'Mohan'}

# %%
type(a)
# Out:
# dict

# %%
# Python data Types

# int,float,complex
# bool,str,tuple,list
# None,set,dict

# %% [markdown]
# ![Python-data-structure.jpg](attachment:Python-data-structure.jpg)
